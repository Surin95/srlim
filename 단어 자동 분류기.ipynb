# %% [markdown]
# ## 엑셀 작업 아르바이트를 하는 친구를 위해 개인적으로 짜준 코드

# %%
import pandas as pd
import numpy as np
import math

#### 1. 데이터 불러 들이기 ####################################################################################
data = pd.read_csv("3500fortext.csv").dropna(axis = 0) ### 따옴표 안에는 너가 불러올 데이터파일의 이름을 .csv 형태로 입력하면 됨

n_para = len(data) # 문단 갯수

ls_sent = []
for i in range(n_para):
    ls_sent.append(len(data['paragraph'][i].split('. ')))

n_sent = sum(ls_sent) # 문장 갯수


#### 2. 문장으로 나누기 ########################################################################################
sent = pd.DataFrame()
for i in range(n_para):
    sent = sent.append(pd.DataFrame(data['paragraph'][i].split('. ')))
sent.reset_index(drop = True)

#### 3. 단어로 나누기 ###########################################################################################
ls_word = []
for i in range(n_sent):
    ls_word.append(len(sent.iloc[i,0].split(' ')))

p = max(ls_word) # 문장 내 단어 최대 갯수

df = pd.DataFrame(np.nan, index = np.arange(2*n_sent), columns = np.arange(p))

for i in range(n_sent):
    for j in range(p):
        if j<len(sent.iloc[i,0].split(' ')):
            df.iloc[2*i,j] = sent.iloc[i,0].split(' ')[j]
        else: df.iloc[2*i,j] = np.nan
            
### 4. 라벨링 ################################################################################################
n = len(df) 

o = ['conduction','conductions','driving','frequencies','frequency',
 'absorbance','absorbances','space‐charge‐limited','scattering',
 'phase','phases','valences','valence','insulating','electronic',
 'doping','forces','force','vibrational','opacity','opacities',
 'mass','holes','solid-state','magnetic','magnetics','thermochemicals',
 'thermochemical','doped','endothermic','endothermics','energies',
 'energy','electric','electrics','excited','barriers','barrier',
 'physical','physicals','diamagnetics','diamagnetic','electrochemical',
 'electrochemicals','intrinsic','transmittance','transmittances',
 'chemical','chemicals','field','fields','semiconductors',
 'semiconductor','HOMO','metallic','metallics','conductive','charge',
 'charges','electrons','electorn','band','bands','atomic','atomics',
 'transport','transports','insulator','insulators','LUMO',
 'magneto-electrical','MLC','electrical','electricals','trapping',
 'stretching','electromagnetic','electromagnetics','metal','metals',
 'carbon-rich','chemically','ferromagnetism','ferromagnetisms',
 'detrapping','electrode','top','bottom','channel','tops','bottoms',
 'channels','pitches','pitch','Cluster','cluster','clusters','BE',
 'dielectric','conventional','layer','layers','MIM','width','widths'
 'TE','electrodes','electrolyte','substrate','substrates','electrolytes',
 'cross-point','terminal','terminals','thick','tox','buffer','buffers',
 'thickness','nanowire','nanowires','surface','surfaces','films','film',
 'vertical','verticals','active','actives','multistack','multistacks',
 'X-point','PMC','multilayer','nanodot', 'nanomesh','selector','switch','switches'
 'NVM','transistors','transitor','mram','FeRAM','memristors',
 'mulit-level','storage','storages','CBRAM','memristor','stt-ram',
 'eNVM','Memory','memories','memory','floating‐gate','ReRAM','rram',
'neuromorphic','neural','Neural','nonvolatile','nonvolatiles',
 'oxram','rom','memristive','memristives','consumption','LRS',
 'low-resistance','Ron','Roff','Ion','compliance','compliances',
 'semi-forming','write','writes','RL','Iset','Iprog','complementary',
 'complementaries','OFF','low','Ioff','Ierase','SCLC','air','airs'
 'bipolar','leakage','Icc','frenkel','ohmic','vapor','vapors',
 'Ileak','IHRS','transition','transitions','Poole','RLRS','Ireset',
 'ILRS','path','paths','precipitation','precipitations','Vset',
 'Vread','TCM','space-charge-limited-current','Vreset','Verase',
 'time','times','dry','dries','Vforming','Vprogram','heat','heats',
 'vacuum','vaccums','resistive','resistives','conductivity',
 'conductivities','high‐resistance','high-resistances','reswitiching',
 'HRS','RH','resistance-state','RHRS','Forming-free','read','reads',
 'breakdown','breakdowns','sweep','sweeps','unipolar','rupture',
 'ruptures','high','dissolution','dissolutions','ON','fast','slow',
 'set','reset','fasts','slows','sets','resets','current–voltage',
 'operation','operations','forming','formation','Electroforming',
 'formations''electroforming','positives','negatives',
 'positive','negative','I-V','Program','erase','program','erases',
 'programs','switching','threshold','thresholds','polarity',
 'poralities','distribution','distributions','structures',
 'structure','plasma','VCM','anneal','voltage','voltages','deposition',
 'depositions','ECM','cycles','cycle','power','powers','process',
 'interface-switching','cycling','application','applications'
 'solution','solutions','filaments','filament','cyclability',
 'cyclabilities','current','currents','self-assembly',
 'thermal-chemical mechanism','duration','durations','resistance',
 'drying','resistances','temperatures','temperature','lifetime',
 'operating','lifetimes','thermals','thermal','pressure','pressures',
 'stability','stabilities','windows','window','angled',
 'RF-sputtering','variability','variabilities','non-uniformity',
 'beam','beams','sputtering','disturbance','disturbances',
 'uniform','uniforms','speed','speeds','e-beam','uniformity',
 'reproducible','endurance','endurances','uniformities',
 'evaporator','evaporators','dispersion','dispersions',
 'retention','retentions','oxidized','spin-coated','distributions',
 'distribution','probabilities','probability',
 'etched','printing','cumulative','cumulatives',
 'Atomic Layer Deposition','patterning','annealing',
 'Fluctuation','Chemical Vapor Deposition','humidity','humidities',
 'laser','lasers','deviations','deviation','Physical Vapor Deposition',
 'lithography','lithographies','ratios','ratio',
 'Pulsed Laser Deposition','photolithography','photolithographies',
 'Non-linearity','Schottky','etching','URS','BRS','CRS',
 'reduction','reductions','ALD','oxidizing','CVD','reliability',
 'PVD','selectivity','selectivities','PLD','material','materials',
 'device','devices','performance','performances','mechanism',
 'mechanisms','environment','environments','synthesis']

mp = ['conduction','conductions','driving','frequencies','frequency',
'absorbance','absorbances','space‐charge‐limited','scattering',
'phase','phases','valences','valence','insulating','electronic',
'doping','forces','force','vibrational','opacity','opacities',
'mass','holes','solid-state','magnetic','magnetics','thermochemicals',
'thermochemical','doped','endothermic','endothermics','energies',
'energy','electric','electrics','excited','barriers','barrier',
'physical','physicals','diamagnetics','diamagnetic','electrochemical',
'electrochemicals','intrinsic','transmittance','transmittances',
'chemical','chemicals','field','fields','semiconductors',
'semiconductor','HOMO','metallic','metallics','conductive','charge',
'charges','electrons','electron','band','bands','atomic','atomics',
'transport','transports','insulator','insulators','LUMO',
'magneto-electrical','MLC','electrical','electricals','trapping',
'stretching','electromagnetic','electromagnetics','metal','metals',
'carbon-rich','chemically','ferromagnetism','ferromagnetisms',
'detrapping','properties','property'] 

ds = ['top','bottom','channel','tops','bottoms',
 'channels','pitches','pitch','Cluster','cluster','clusters','BE',
'dielectric','conventional','layer','layers','MIM','width','widths'
 'TE','electrodes','electrode','electrolyte','substrate','substrates','electrolytes',
'cross-point','terminal','terminals','thick','tox','buffer','buffers',
 'thickness','nanowire','nanowires','surface','surfaces','films','film',
'vertical','verticals','active','actives','multistack','multistacks',
 'X-point','PMC','multilayer','nanodot', 'nanomesh','structure','structures'] 

da = ['selector','switch','switches'
 'NVM','transistors','transitor','mram','FeRAM','memristors',
'mulit-level','storage','storages','CBRAM','memristor','stt-ram',
 'eNVM','Memory','memories','memory','floating‐gate','ReRAM','rram',
'neuromorphic','neural','Neural','nonvolatile','nonvolatiles',
 'oxram','rom','applications','application'] 

pp = ['power','Power','consumtion','consumptions'] 

pc = ['compliance','compliances','Ileak','IHRS','ILRS','Iset','Iprog','Ion',
      'leakage','Icc','Ioff','Ierase','Ireset','current','currents','ions','Ions'
     'ion']   

pv = ['Vforming','Vprogram','Vreset','Verase','Vset','Vread',
     'voltage','voltages']

pr = ['resistive','resistives','conductivity','conductivities',
      'high‐resistance','high-resistances','HRS','RH',
      'resistance-state','RHRS','low-resistance','Ron','Roff','LRS','RL','RLRS',
      'resistance','resistances'] 

po = ['semi-forming','write','writes','complementary',
 'complementaries','OFF','Forming-free','read','reads',
 'breakdown','breakdowns','sweep','sweeps','unipolar','rupture',
 'ruptures','high','dissolution','dissolutions','ON','fast','slow',
 'set','reset','fasts','slows','sets','resets','current–voltage',
 'operation','operations','forming','formation','Electroforming',
 'formations''electroforming','positives','negatives',
 'positive','negative','I-V','Program','erase','program','erases',
 'programs','switching','threshold','thresholds','polarity',
 'poralities','reswitiching','low','bipolar','operating','SET','RESET']  

ps = ['speed']   

pe = ['cycles','cycle','cycling','cyclability',
     'cyclabilities','endurance','endurances']  

pre = ['duration','durations','lifetime','lifetimes','retention',
      'retentions']   

pab = ['stability','stabilities','windows','window','variability',
       'variabilities','non-uniformity','disturbance','disturbances',
      'uniform','uniforms','distributions','distribution','probabilities',
       'probability','cumulative','cumulatives','Fluctuation','uniformity',
       'uniformities','reproducible','dispersion','dispersions',
      'deviations','deviation','reliability','reliabilities']    

plec = ['selectivity','selectivities','ratio','Non-linearity']     

mc = ['URS','BRS','CRS','transition','transitions','Poole',
 'path','paths','precipitation','precipitations',
 'TCM','space-charge-limited-current','frenkel','ohmic','SCLC',
     'filaments','filament','interface-switching','thermal-chemical mechanism',
     'Schottky','VCM','ECM','reduction','reductions','oxidized',
     'oxidizing','mechanism','mechanisms']     

e = ['time','times','dry','dries','heat','heats','vacuum','vaccums',
    'air','airs','temperatures','temperature','environment','environments',
    'pressure','pressures','humidity','humidities']      

s = ['spin-coated','etched','printing','Atomic Layer Deposition','patterning',
     'annealing','Chemical Vapor Deposition','laser','lasers',
     'Physical Vapor Deposition','lithography','lithographies',
     'Pulsed Laser Deposition','photolithography','photolithographies','etching',
     'ALD','CVD','thermals','thermal','angled','RF-sputtering','beam',
     'beams','sputtering','e-beam','evaporator','evaporators','plasma','anneal',
    'vapor','vapors','drying','self-assembly','solution','solutions',
    'deposition','depositions','PVD','process','processes','patterning','PLD'
    'synthesis']    

d = ['device','devices','device,','devices,','Device','Devices']

def isNaN(string):
    return string != string

for i in range(int(n/2)):
    for j in range(p):
        if ((df.iloc[2*i,j] not in o) and (df.iloc[2*i,j] not in mp) and (df.iloc[2*i,j] not in ds) 
            and (df.iloc[2*i,j] not in da) and (df.iloc[2*i,j] not in pp) and (df.iloc[2*i,j] not in pc) 
            and (df.iloc[2*i,j] not in pv) and (df.iloc[2*i,j] not in pr) and (df.iloc[2*i,j] not in po) 
            and (df.iloc[2*i,j] not in ps) and (df.iloc[2*i,j] not in pe) and (df.iloc[2*i,j] not in pre) 
            and (df.iloc[2*i,j] not in pab) and (df.iloc[2*i,j] not in plec) and (df.iloc[2*i,j] not in mc) 
            and (df.iloc[2*i,j] not in e) and (df.iloc[2*i,j] not in s) and (df.iloc[2*i,j] not in d) 
            and isNaN(df.iloc[2*i,j]) != True):df.iloc[2*i+1,j] = 'o' 
        elif (df.iloc[2*i,j] in mp) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-mp-o'
        elif (df.iloc[2*i,j] in ds) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-ds-o'
        elif (df.iloc[2*i,j] in da) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-da-o'
        elif (df.iloc[2*i,j] in pp) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-pp-o'
        elif (df.iloc[2*i,j] in pc) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-pc-o'
        elif (df.iloc[2*i,j] in pv) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-pv-o'
        elif (df.iloc[2*i,j] in pr) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-pr-o'
        elif (df.iloc[2*i,j] in po) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-po-o'
        elif (df.iloc[2*i,j] in ps) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-ps-o'
        elif (df.iloc[2*i,j] in pe) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-pe-o'
        elif (df.iloc[2*i,j] in pre) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-pre-o'
        elif (df.iloc[2*i,j] in pab) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-pab-o'
        elif (df.iloc[2*i,j] in plec) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-plec-o'
        elif (df.iloc[2*i,j] in mc) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-mc-o'
        elif (df.iloc[2*i,j] in e) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-e-o'
        elif (df.iloc[2*i,j] in s) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-s-o'
        elif (df.iloc[2*i,j] in d) and isNaN(df.iloc[2*i,j]) != True:
            df.iloc[2*i+1,j] = 'B-o-d-o'

#### 5. ,나 .으로 끝나는 단어들 처리 #############################################################################            
for i in range(int(n/2)):
    for j in range(p):
        if type(df.iloc[2*i,j]) == str and df.iloc[2*i,j][-1] == (',' or '.') :
            if (df.iloc[2*i,j][:-1] in mp) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-mp-o'
            elif (df.iloc[2*i,j][:-1] in ds) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-ds-o'
            elif (df.iloc[2*i,j][:-1] in da) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-da-o'
            elif (df.iloc[2*i,j][:-1] in pp) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-pp-o'
            elif (df.iloc[2*i,j][:-1] in pc) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-pc-o'
            elif (df.iloc[2*i,j][:-1] in pv) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-pv-o'
            elif (df.iloc[2*i,j][:-1] in pr) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-pr-o'
            elif (df.iloc[2*i,j][:-1] in po) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-po-o'
            elif (df.iloc[2*i,j][:-1] in ps) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-ps-o'
            elif (df.iloc[2*i,j][:-1] in pe) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-pe-o'
            elif (df.iloc[2*i,j][:-1] in pre) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-pre-o'
            elif (df.iloc[2*i,j][:-1] in pab) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-pab-o'
            elif (df.iloc[2*i,j][:-1] in plec) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-plec-o'
            elif (df.iloc[2*i,j][:-1] in mc) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-mc-o'
            elif (df.iloc[2*i,j][:-1] in e) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-e-o'
            elif (df.iloc[2*i,j][:-1] in s) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-s-o'
            elif (df.iloc[2*i,j][:-1] in d) and isNaN(df.iloc[2*i,j]) != True:
                df.iloc[2*i+1,j] = 'B-o-d-o' 
            
#### 6. 'B-'가 연속으로 나타나면 두번째부터는 'I-'로 변경 ############################################################            
for i in range(int(n/2)):
    for j in range(1,p)[::-1]:
        if (j>=3 and type(df.iloc[2*i+1, j-3]) == type(df.iloc[2*i+1, j-2]) == 
            type(df.iloc[2*i+1, j-1]) == type(df.iloc[2*i+1, j]) == str):
            # 4개 연속
            if (df.iloc[2*i+1,j-3].startswith('B-') and df.iloc[2*i+1,j-2].startswith('B-') and 
                df.iloc[2*i+1,j-1].startswith('B-') and df.iloc[2*i+1,j].startswith('B-')):
                    df.iloc[2*i+1,j] = df.iloc[2*i+1,j].replace('B-','I-') 
                    df.iloc[2*i+1,j-1] = df.iloc[2*i+1,j-1].replace('B-','I-') 
                    df.iloc[2*i+1,j-2] = df.iloc[2*i+1,j-2].replace('B-','I-') 
            # 3개 연속
            if (df.iloc[2*i+1,j-2].startswith('B-') and df.iloc[2*i+1,j-1].startswith('B-') and 
                df.iloc[2*i+1,j].startswith('B-')):
                    df.iloc[2*i+1,j] = df.iloc[2*i+1,j].replace('B-','I-') 
                    df.iloc[2*i+1,j-1] = df.iloc[2*i+1,j-1].replace('B-','I-') 
            # 2개 연속
            elif (type(df.iloc[2*i+1, j-1]) == type(df.iloc[2*i+1, j]) == str):
                if (df.iloc[2*i+1,j-1].startswith('B-') and df.iloc[2*i+1,j].startswith('B-')):
                    df.iloc[2*i+1,j] = df.iloc[2*i+1,j].replace('B-','I-')    
        elif (j>=2 and type(df.iloc[2*i+1, j-2]) == type(df.iloc[2*i+1, j-1]) == type(df.iloc[2*i+1, j]) == str):
            # 3개 연속
            if (df.iloc[2*i+1,j-2].startswith('B-') and df.iloc[2*i+1,j-1].startswith('B-') and 
                df.iloc[2*i+1,j].startswith('B-')):
                    df.iloc[2*i+1,j] = df.iloc[2*i+1,j].replace('B-','I-') 
                    df.iloc[2*i+1,j-1] = df.iloc[2*i+1,j-1].replace('B-','I-') 
            # 2개 연속
            elif (type(df.iloc[2*i+1, j-1]) == type(df.iloc[2*i+1, j]) == str):
                if (df.iloc[2*i+1,j-1].startswith('B-') and df.iloc[2*i+1,j].startswith('B-')):
                    df.iloc[2*i+1,j] = df.iloc[2*i+1,j].replace('B-','I-')        
        elif type(df.iloc[2*i+1, j-1]) == type(df.iloc[2*i+1, j]) == str:
            if (df.iloc[2*i+1,j-1].startswith('B-') and df.iloc[2*i+1,j].startswith('B-')):
                    df.iloc[2*i+1,j] = df.iloc[2*i+1,j].replace('B-','I-')                  
                
#### 7. 결과 저장 ###########################################################################################            
df.to_csv("3500surin.csv") ### 따옴표 안에는 너가 결과파일로 내보낼 파일의 이름을 .csv 형태로 입력하면 됨
